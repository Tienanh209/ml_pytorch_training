# %%
"""
Exercise 2: Building PyTorch Models
PyTorch Workflow Fundamentals - Module 2

This exercise covers:
- Creating models with nn.Module
- Understanding nn.Parameter
- Implementing the forward() method
- Inspecting model parameters
- Making predictions

Learning Mottos:
- If in doubt, run the code!
- Experiment, experiment, experiment!
- Visualize, visualize, visualize!
"""
# Out:
# '\nExercise 2: Building PyTorch Models\nPyTorch Workflow Fundamentals - Module 2\n\nThis exercise covers:\n- Creating models with nn.Module\n- Understanding nn.Parameter\n- Implementing the forward() method\n- Inspecting model parameters\n- Making predictions\n\nLearning Mottos:\n- If in doubt, run the code!\n- Experiment, experiment, experiment!\n- Visualize, visualize, visualize!\n'

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# Set random seed for reproducibility
torch.manual_seed(42)

# %%
print("=" * 60)
print("Part 1: Creating the Linear Regression Model")
print("=" * 60)
# Out:
# ============================================================
# Part 1: Creating the Linear Regression Model
# ============================================================

# %%
class LinearRegressionModel(nn.Module):
    """
    Simple linear regression model: y = weight * X + bias
    """

    def __init__(self):
        super().__init__()
        # TODO: Create learnable parameters
        self.weight = nn.Parameter(torch.randn(1))
        self.bias = nn.Parameter(torch.randn(1))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # TODO: Implement forward pass
        return self.weight * x + self.bias

# %%
print(nn.Parameter(torch.randn(1)))
# Out:
# Parameter containing:
# tensor([0.3367], requires_grad=True)

# %%
# TODO: Create model instance
model = LinearRegressionModel()

print("Model created successfully!")
print(f"\nModel architecture:\n{model}")
# Out:
# Model created successfully!
#
# Model architecture:
# LinearRegressionModel()

# %%
print("\n" + "=" * 60)
print("Part 2: Understanding nn.Parameter")
print("=" * 60)
# Out:
# ============================================================
# Part 2: Understanding nn.Parameter
# ============================================================

# %%
# TODO: Inspect parameters
print("\nModel parameters:")
for name, param in model.named_parameters():
    print(f"  {name}: {param.item():.4f} (requires_grad={param.requires_grad})")
# Out:
# Model parameters:
#   weight: 0.1288 (requires_grad=True)
#   bias: 0.2345 (requires_grad=True)

# %%
# TODO: Show parameter details
print(f"\nWeight details:")
print(f"  Value: {model.weight.item():.4f}")
print(f"  Shape: {model.weight.shape}")
print(f"  Gradient enabled: {model.weight.requires_grad}")

print(f"\nBias details:")
print(f"  Value: {model.bias.item():.4f}")
print(f"  Shape: {model.bias.shape}")
print(f"  Gradient enabled: {model.bias.requires_grad}")
# Out:
# Weight details:
#   Value: 0.1288
#   Shape: torch.Size([1])
#   Gradient enabled: True
#
# Bias details:
#   Value: 0.2345
#   Shape: torch.Size([1])
#   Gradient enabled: True

# %%
print("\n" + "=" * 60)
print("Part 3: Making Predictions")
print("=" * 60)
# Out:
# ============================================================
# Part 3: Making Predictions
# ============================================================

# %%
# Create test data
X_test = torch.tensor([[0.0], [0.5], [1.0]])

# %%
# TODO: Make predictions
with torch.no_grad():
    predictions = model(X_test)

print(f"\nInput values:\n{X_test.flatten()}")
print(f"\nPredictions:\n{predictions.flatten()}")
print(f"\nExpected (if weight=0.7, bias=0.3):\n{0.7 * X_test.flatten() + 0.3}")
# Out:
# Input values:
# tensor([0.0000, 0.5000, 1.0000])
#
# Predictions:
# tensor([0.2345, 0.2989, 0.3633])
#
# Expected (if weight=0.7, bias=0.3):
# tensor([0.3000, 0.6500, 1.0000])

# %%
print("\n" + "=" * 60)
print("Part 4: Visualizing Initial Predictions")
print("=" * 60)
# Out:
# ============================================================
# Part 4: Visualizing Initial Predictions
# ============================================================

# %%
# Create data for visualization
X = torch.arange(0, 1, 0.02).unsqueeze(dim=1)
y_true = 0.7 * X + 0.3

# %%
# TODO: Make predictions
with torch.no_grad():
    y_pred = model(X)

# %%
# TODO: Visualize
plt.figure(figsize=(10, 6))
plt.scatter(X, y_true, c='b', s=50, alpha=0.6, label='True data (y=0.7X+0.3)')
plt.scatter(X, y_pred, c='r', s=50, alpha=0.6, label='Model predictions (untrained)')
plt.plot(X, y_pred, 'r--', alpha=0.3)
plt.xlabel('X', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.legend(fontsize=10)
plt.title(f'Initial Predictions (Before Training)\nweight={model.weight.item():.3f}, bias={model.bias.item():.3f}',
          fontsize=14)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("Visualization created!")
print("Note: Predictions don't match yet because model is untrained.")
# Out:
# Visualization created!
# Note: Predictions don't match yet because model is untrained.

# %%
print("\n" + "=" * 60)
print("Part 5: Inspecting Model State")
print("=" * 60)
# Out:
# ============================================================
# Part 5: Inspecting Model State
# ============================================================

# %%
# TODO: Count parameters
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"\nTotal parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
# Out:
# Total parameters: 2
# Trainable parameters: 2

# %%
# TODO: Show model state dict
print(f"\nModel state_dict keys:")
for key in model.state_dict().keys():
    print(f"  {key}")
# Out:
# Model state_dict keys:
#   weight
#   bias

# %%
print("\n" + "=" * 60)
print("Exercises")
print("=" * 60)
# Out:
# ============================================================
# Exercises
# ============================================================

# %%
# Exercise 1: Create a model with different initialization
print("\nExercise 1: Different initialization")
# TODO: Initialize weight=0.0, bias=0.0
# TODO: Visualize predictions
print("Tip: Modify the nn.Parameter initialization in __init__")

class LinearRegressionModelZeros(nn.Module):
    """
    Simple linear regression model: y = weight * X + bias
    """

    def __init__(self):
        super().__init__()
        # TODO: Create learnable parameters
        self.weight = nn.Parameter(torch.zeros(1))
        self.bias = nn.Parameter(torch.zeros(1))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # TODO: Implement forward pass
        return self.weight * x + self.bias

model = LinearRegressionModelZeros()
print("\nModel parameters:")
for name, param in model.named_parameters():
    print(f" {name}: {param.item():.4f} (requires_grad={param.requires_grad})")

X_test = torch.tensor([[0.2], [0.5], [0.1], [0.3]])
with torch.no_grad():
    predictions = model(X_test)

X = torch.arange(0, 1, 0.02).unsqueeze(dim=1)
y_true = 0.7 * X + 0.3
with torch.no_grad():
    y_pred = model(X)

plt.figure(figsize=(10, 6))
plt.scatter(X, y_true, c='b', s=50, alpha=0.6, label='True data (y=0.7X+0.3)')
plt.scatter(X, y_pred, c='r', s=50, alpha=0.6, label='Model predictions (untrained)')
plt.plot(X, y_pred, 'r--', alpha=0.3)
plt.xlabel('X', fontsize=12)
plt.ylabel('Y', fontsize=12)
plt.legend(fontsize=10)
plt.title(f'Initial Predictions (Before Training)\nweight={model.weight.item():.3f}, bias={model.bias.item():.3f}',
          fontsize=14)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Exercise 1: Different initialization
# Tip: Modify the nn.Parameter initialization in __init__
#
# Model parameters:
#  weight: 0.0000 (requires_grad=True)
#  bias: 0.0000 (requires_grad=True)

# %%
# Exercise 2: Multiple input features
print("\nExercise 2: Multiple input features")
print("Tip: Use nn.Linear(input_size, 1) for multiple features")

class MultiFeatureLinearRegression(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        # TODO: Implement this
        # Hint: Use nn.Linear instead of individual parameters
        super().__init__()
        self.linear = nn.Linear(input_size, 1,)

    def forward(self, x):
        # TODO: Implement this
        return self.linear(x)
# Out:
# Exercise 2: Multiple input features
# Tip: Use nn.Linear(input_size, 1) for multiple features

# %%
# Exercise 3: Add activation function
print("\nExercise 3: Add non-linearity")
print("Tip: Use torch.relu(), torch.sigmoid(), or torch.tanh()")

class NonLinearModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.weight = nn.Parameter(torch.randn(1))
        self.bias = nn.Parameter(torch.randn(1))
        self.activation = torch.relu
        pass

    def forward(self, x):
        y = self.weight * x + self.bias
        return self.activation(y)
# Out:
# Exercise 3: Add non-linearity
# Tip: Use torch.relu(), torch.sigmoid(), or torch.tanh()

# %%
# Exercise 4: Print model summary
print("\nExercise 4: Model summary")
# TODO: Print layer-by-layer summary
# TODO: Count parameters per layer
print("Tip: Iterate over model.named_parameters() and print details")

model = MultiFeatureLinearRegression(5)

total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"\nTotal parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
# Out:
# Exercise 4: Model summary
# Tip: Iterate over model.named_parameters() and print details
#
# Total parameters: 6
# Trainable parameters: 6

# %%
# Exercise 5: Model comparison
print("\nExercise 5: Model comparison")
# TODO: Create multiple models with different initializations
# TODO: Compare their predictions
# TODO: Visualize all predictions on same plot
print("Tip: Create 3 models with different random seeds")
# Create models
torch.manual_seed(42)
model1 = LinearRegressionModel()

torch.manual_seed(9)
model2 = MultiFeatureLinearRegression(3)

torch.manual_seed(3)
model3 = NonLinearModel()

# Data
X = torch.arange(0, 1, 0.02).unsqueeze(dim=1)
y_true = 0.7 * X + 0.3
X3 = torch.cat([X, X, X], dim=1)
print(X3.shape)
# Predictions
with torch.no_grad():
    y_pred1 = model1(X)
    y_pred2 = model2(X3)
    y_pred3 = model3(X)

# Plot
plt.figure(figsize=(10, 6))
plt.scatter(X, y_true, c='b', s=50, alpha=0.6, label='True data')

plt.plot(X, y_pred1, 'r--', label='Model 1')
plt.plot(X, y_pred2, 'g--', label='Model 2')
plt.plot(X, y_pred3, 'm--', label='Model 3 (NonLinear)')

plt.xlabel("X")
plt.ylabel("y")
plt.title("Model Comparison (Untrained Predictions)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Exercise 5: Model comparison
# Tip: Create 3 models with different random seeds
# torch.Size([50, 3])

# %%
print("\n" + "=" * 60)
print("Exercise 2 Complete!")
print("Remember: If in doubt, run the code!")
print("=" * 60)
# Out:
# ============================================================
# Exercise 2 Complete!
# Remember: If in doubt, run the code!
# ============================================================
