# %%
"""
Exercise 1: Data Preparation
PyTorch Workflow Fundamentals - Module 2

This exercise covers:
- Creating synthetic data for linear regression
- Visualizing data distributions
- Splitting data into train/val/test sets
- Understanding the importance of data splits

Learning Mottos:
- If in doubt, run the code!
- Experiment, experiment, experiment!
- Visualize, visualize, visualize!
"""
# Out:
# '\nExercise 1: Data Preparation\nPyTorch Workflow Fundamentals - Module 2\n\nThis exercise covers:\n- Creating synthetic data for linear regression\n- Visualizing data distributions\n- Splitting data into train/val/test sets\n- Understanding the importance of data splits\n\nLearning Mottos:\n- If in doubt, run the code!\n- Experiment, experiment, experiment!\n- Visualize, visualize, visualize!\n'

# %%
import torch
import matplotlib.pyplot as plt

# Set random seed for reproducibility
torch.manual_seed(42)

# %%
print("=" * 60)
print("Part 1: Creating Synthetic Data")
print("=" * 60)
# Out:
# ============================================================
# Part 1: Creating Synthetic Data
# ============================================================

# %%
# TODO: Define known parameters
weight = 0.7
bias = 0.3

# TODO: Create input data
start = 0
end = 1
step = 0.02
X = torch.arange(start, end, step).unsqueeze(dim=1)

# TODO: Create output data using linear formula
y = weight * X + bias

print(f"X shape: {X.shape}")
print(f"y shape: {y.shape}")
print(f"Total samples: {len(X)}")
print(f"\nFirst 5 X values:\n{X[:5]}")
print(f"\nFirst 5 y values:\n{y[:5]}")
# Out:
# X shape: torch.Size([50, 1])
# y shape: torch.Size([50, 1])
# Total samples: 50
#
# First 5 X values:
# tensor([[0.0000],
#         [0.0200],
#         [0.0400],
#         [0.0600],
#         [0.0800]])
#
# First 5 y values:
# tensor([[0.3000],
#         [0.3140],
#         [0.3280],
#         [0.3420],
#         [0.3560]])

# %%
print("\n" + "=" * 60)
print("Part 2: Visualizing the Data")
print("=" * 60)
# Out:
# ============================================================
# Part 2: Visualizing the Data
# ============================================================

# %%
# TODO: Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(X, y, c='b', s=50, alpha=0.6, label='Data points')
plt.plot(X, weight * X + bias, 'r-', linewidth=2,
         label=f'True line: y = {weight}X + {bias}')
plt.xlabel('X', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.legend(fontsize=10)
plt.title('Linear Regression Data', fontsize=14)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("Visualization created!")
print("Motto: Visualize, visualize, visualize!")
# Out:
# Visualization created!
# Motto: Visualize, visualize, visualize!

# %%
print("\n" + "=" * 60)
print("Part 3: Splitting the Data")
print("=" * 60)
# Out:
# ============================================================
# Part 3: Splitting the Data
# ============================================================

# %%
# TODO: Calculate split points
train_split = int(0.7 * len(X))
val_split = int(0.85 * len(X))

print(f"Total samples: {len(X)}")
print(f"Train split index: {train_split}")
print(f"Val split index: {val_split}")
# Out:
# Total samples: 50
# Train split index: 35
# Val split index: 42

# %%
# TODO: Split the data
X_train, y_train = X[:train_split], y[:train_split]
X_val, y_val = X[train_split:val_split], y[train_split:val_split]
X_test, y_test = X[val_split:], y[val_split:]

print(f"\nTrain size: {len(X_train)} ({len(X_train)/len(X)*100:.1f}%)")
print(f"Validation size: {len(X_val)} ({len(X_val)/len(X)*100:.1f}%)")
print(f"Test size: {len(X_test)} ({len(X_test)/len(X)*100:.1f}%)")
# Out:
# Train size: 35 (70.0%)
# Validation size: 7 (14.0%)
# Test size: 8 (16.0%)

# %%
print("\n" + "=" * 60)
print("Part 4: Visualizing Data Splits")
print("=" * 60)
# Out:
# ============================================================
# Part 4: Visualizing Data Splits
# ============================================================

# %%
# TODO: Create visualization of splits
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, c='b', s=50, alpha=0.6, label='Train (70%)')
plt.scatter(X_val, y_val, c='g', s=50, alpha=0.6, label='Validation (15%)')
plt.scatter(X_test, y_test, c='r', s=50, alpha=0.6, label='Test (15%)')
plt.xlabel('X', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.legend(fontsize=10)
plt.title('Data Splits: Train/Validation/Test', fontsize=14)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("Data splits visualized!")
# Out:
# Data splits visualized!

# %%
print("\n" + "=" * 60)
print("Part 5: Understanding the Splits")
print("=" * 60)
# Out:
# ============================================================
# Part 5: Understanding the Splits
# ============================================================

# %%
# TODO: Print statistics for each split
print("\nTraining set statistics:")
print(f"  X range: [{X_train.min():.3f}, {X_train.max():.3f}]")
print(f"  y range: [{y_train.min():.3f}, {y_train.max():.3f}]")

print("\nValidation set statistics:")
print(f"  X range: [{X_val.min():.3f}, {X_val.max():.3f}]")
print(f"  y range: [{y_val.min():.3f}, {y_val.max():.3f}]")

print("\nTest set statistics:")
print(f"  X range: [{X_test.min():.3f}, {X_test.max():.3f}]")
print(f"  y range: [{y_test.min():.3f}, {y_test.max():.3f}]")
# Out:
# Training set statistics:
#   X range: [0.000, 0.680]
#   y range: [0.300, 0.776]
#
# Validation set statistics:
#   X range: [0.700, 0.820]
#   y range: [0.790, 0.874]
#
# Test set statistics:
#   X range: [0.840, 0.980]
#   y range: [0.888, 0.986]

# %%
print("\n" + "=" * 60)
print("Exercises")
print("=" * 60)
# Out:
# ============================================================
# Exercises
# ============================================================

# %%
print("=" * 60)
# Exercise 1: Change weight and bias
print("Exercise 1: Change weight and bias")
# TODO: Try weight=1.5, bias=0.5
# TODO: Try weight=-0.5, bias=0.8
print("Tip: Modify the weight and bias variables at the top of the script")
print("Try different values and visualize:")
print("=" * 60)
print("Weight=1.5, Bias=0.5")
weight=1.5
bias=0.5

X = torch.arange(start, end, 0.01).unsqueeze(dim=1)
y = weight * X + bias
# print(X.shape, y.shape)

plt.figure(figsize=(10, 6))
plt.scatter(X, y, c='b', s=25, alpha=0.6, label='Data points')
plt.plot(X, weight * X + bias, 'r-', linewidth=2,
         label=f'True line: y = {weight}X + {bias}')
plt.xlabel('X', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.legend(fontsize=10)
plt.title('Linear Regression Data', fontsize=14)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# ============================================================
# Exercise 1: Change weight and bias
# Tip: Modify the weight and bias variables at the top of the script
# Try different values and visualize:
# ============================================================
# Weight=1.5, Bias=0.5

# %%
print("=" * 60)
print("Weight=-0.5, Bias=0.8")
weight=-0.5 
bias=0.8
y = weight * X + bias

plt.figure(figsize=(10, 6))
plt.scatter(X, y,c='b', s=25, alpha=0.6, label='Data points')
plt.plot(X, weight * X + bias, 'r-', linewidth=2, label=f'True line: y = {weight}X + {bias}')
plt.xlabel('X', fontsize=12)
plt.ylabel('Y', fontsize=12)
plt.legend(fontsize=10)
plt.title('Linear Regression Data', fontsize=14)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# ============================================================
# Weight=-0.5, Bias=0.8

# %%
# Exercise 2: Experiment with split ratios
print("=" * 60)
print("Exercise 2: Experiment with split ratios")
print("Try different train/val/test ratios:")
# TODO: Try 80/10/10 split
# TODO: Try 60/20/20 split
print("Tip: Modify the train_split and val_split calculations")
# Out:
# ============================================================
# Exercise 2: Experiment with split ratios
# Try different train/val/test ratios:
# Tip: Modify the train_split and val_split calculations

# %%
print("=" * 60)
train_split = int(0.8 * len(X))
val_split = int(0.9 * len(X))
print(f"Total samples: {len(X)}")
print(f"Train split index: {train_split}")
print(f"Val split index: {val_split}")

X_train, y_train = X[:train_split], y[:train_split]
X_val, y_val = X[train_split:val_split], y[train_split:val_split]
X_test, y_test = X[val_split:], y[val_split:]

print(f"\nTrain size: {len(X_train)} ({len(X_train)/len(X)*100:.1f}%)")
print(f"Validation size: {len(X_val)} ({len(X_val)/len(X)*100:.1f}%)")
print(f"Test size: {len(X_test)} ({len(X_test)/len(X)*100:.1f}%)")

plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, c='b', s=25, alpha=0.6, label='Train (80%)')
plt.scatter(X_val, y_val, c='g', s=25, alpha=0.6, label='Validation (10%)')
plt.scatter(X_test, y_test, c='r', s=25, alpha=0.6, label='Test (10%)')
plt.xlabel('X', fontsize=12)
plt.ylabel('Y', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.6)
plt.title('Data splits: Train/Validation/Test', fontsize=14)
plt.tight_layout()
plt.show()

print("\nTraining set statistics:")
print(f"  X range: [{X_train.min():.3f}, {X_train.max():.3f}]")
print(f"  y range: [{y_train.min():.3f}, {y_train.max():.3f}]")

print("\nValidation set statistics:")
print(f"  X range: [{X_val.min():.3f}, {X_val.max():.3f}]")
print(f"  y range: [{y_val.min():.3f}, {y_val.max():.3f}]")

print("\nTest set statistics:")
print(f"  X range: [{X_test.min():.3f}, {X_test.max():.3f}]")
print(f"  y range: [{y_test.min():.3f}, {y_test.max():.3f}]")
# Out:
# ============================================================
# Total samples: 100
# Train split index: 80
# Val split index: 90
#
# Train size: 80 (80.0%)
# Validation size: 10 (10.0%)
# Test size: 10 (10.0%)
# Training set statistics:
#   X range: [0.000, 0.790]
#   y range: [0.405, 0.800]
#
# Validation set statistics:
#   X range: [0.800, 0.890]
#   y range: [0.355, 0.400]
#
# Test set statistics:
#   X range: [0.900, 0.990]
#   y range: [0.305, 0.350]

# %%
print("=" * 60)
train_split = int(0.9 * len(X))
val_split = int(0.95 * len(X))
print(f"Total samples: {len(X)}")
print(f"Train split index: {train_split}")
print(f"Val split index: {val_split}")

X_train, y_train = X[:train_split], y[:train_split]
X_val, y_val = X[train_split:val_split], y[train_split:val_split]
X_test, y_test = X[val_split:], y[val_split:]

print(f"\nTrain size: {len(X_train)} ({len(X_train)/len(X)*100:.1f}%)")
print(f"Validation size: {len(X_val)} ({len(X_val)/len(X)*100:.1f}%)")
print(f"Test size: {len(X_test)} ({len(X_test)/len(X)*100:.1f}%)")

plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, c='b', s=25, alpha=0.6, label='Train (90%)')
plt.scatter(X_val, y_val, c='g', s=25, alpha=0.6, label='Validation (5%)')
plt.scatter(X_test, y_test, c='r', s=25, alpha=0.6, label='Test (5%)')
plt.xlabel('X', fontsize=12)
plt.ylabel('Y', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.6)
plt.title('Data splits: Train/Validation/Test', fontsize=14)
plt.tight_layout()
plt.show()

print("\nTraining set statistics:")
print(f"  X range: [{X_train.min():.3f}, {X_train.max():.3f}]")
print(f"  y range: [{y_train.min():.3f}, {y_train.max():.3f}]")

print("\nValidation set statistics:")
print(f"  X range: [{X_val.min():.3f}, {X_val.max():.3f}]")
print(f"  y range: [{y_val.min():.3f}, {y_val.max():.3f}]")

print("\nTest set statistics:")
print(f"  X range: [{X_test.min():.3f}, {X_test.max():.3f}]")
print(f"  y range: [{y_test.min():.3f}, {y_test.max():.3f}]")
# Out:
# ============================================================
# Total samples: 100
# Train split index: 90
# Val split index: 95
#
# Train size: 90 (90.0%)
# Validation size: 5 (5.0%)
# Test size: 5 (5.0%)
# Training set statistics:
#   X range: [0.000, 0.890]
#   y range: [0.355, 0.800]
#
# Validation set statistics:
#   X range: [0.900, 0.940]
#   y range: [0.330, 0.350]
#
# Test set statistics:
#   X range: [0.950, 0.990]
#   y range: [0.305, 0.325]

# %%
# Exercise 3: Add noise to the data
print("\nExercise 3: Add noise to the data")
# TODO: Add Gaussian noise to y
# TODO: Visualize noisy data
print("Tip: y_noisy = weight * X + bias + torch.randn_like(y) * 0.05")
y_noisy = weight * X + bias + torch.randn_like(y) * 0.03
plt.figure(figsize=(10, 6))
plt.scatter(X, y, c='b', s=50, alpha=0.6, label='Data points')
plt.scatter(X, y_noisy, c='g', s=50, alpha=0.6, label='Noisy Data points')
plt.plot(X, weight * X + bias, 'r-', linewidth=2,
         label=f'True line: y = {weight}X + {bias}')
plt.xlabel('X', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.legend(fontsize=10)
plt.title('Linear Regression Data', fontsize=14)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Exercise 3: Add noise to the data
# Tip: y_noisy = weight * X + bias + torch.randn_like(y) * 0.05

# %%
# Exercise 4: Create non-linear data
print("\nExercise 4: Create non-linear data")
# TODO: Create quadratic data: y = ax^2 + bx + c
# TODO: Visualize the relationship
print("Tip: y = 0.5 * X**2 + 0.3 * X + 0.1")
y = 0.5 * X**2 + 0.3 * X + 0.1
plt.figure(figsize=(10, 6))
plt.scatter(X, y, c='b', s=25, alpha=0.6, label='Data points')
plt.plot(X, 0.5 * X**2 + 0.3 * X + 0.1, 'r-', linewidth=2,
         label=f'True line: y = 0.5 * X**2 + 0.3 * X + 0.1')
plt.xlabel('X', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.legend(fontsize=10)
plt.title('Linear Regression Data', fontsize=14)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Exercise 4: Create non-linear data
# Tip: y = 0.5 * X**2 + 0.3 * X + 0.1

# %%
# Exercise 5: Data exploration
print("\nExercise 5: Data exploration")
print("Answer these questions:")
print("  - What happens if X is not sorted?")
print(" Answer: If X is not sorted: results can be wrong (plots look messy, interpolation/calculations fail or give incorrect values)")
print("  - What happens with very few data points (e.g., step=0.1)?")
print(" Answer: Few data points (step = 0.1): faster, but rough and less accurate.")
print("  - What happens with many data points (e.g., step=0.01)?")
print(" Answer: Many data points (step = 0.01): smoother and more accurate, but slower and uses more memory.")

print("\nTip: Modify the 'step' variable and observe the changes")

print("\n" + "=" * 60)
print("Exercise 1 Complete!")
print("Remember: Experiment, experiment, experiment!")
print("=" * 60)
# Out:
# Exercise 5: Data exploration
# Answer these questions:
#   - What happens if X is not sorted?
#  Answer: If X is not sorted: results can be wrong (plots look messy, interpolation/calculations fail or give incorrect values)
#   - What happens with very few data points (e.g., step=0.1)?
#  Answer: Few data points (step = 0.1): faster, but rough and less accurate.
#   - What happens with many data points (e.g., step=0.01)?
#  Answer: Many data points (step = 0.01): smoother and more accurate, but slower and uses more memory.
#
# Tip: Modify the 'step' variable and observe the changes
#
# ============================================================
# Exercise 1 Complete!
# Remember: Experiment, experiment, experiment!
# ============================================================
